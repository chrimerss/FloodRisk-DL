# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
with h5py.File('../src/data_preparation/training.h5', 'r') as f:
    arr= f['train/HOU002_110mm/0002'][:]
    # print(f['train/HOU002_110mm'].keys())

# %%
arr.shape
# Out:
# (3, 1024, 1024)

# %%
fig, axes= plt.subplots(1,2,figsize=(8,8))
axes[0].imshow(arr[0])
axes[1].imshow(arr[2])

# %%
plt.imshow(arr[1])

# %%
with h5py.File('test', 'w') as h5f:
    train_group= h5f.create_group('train')
    group=train_group
    for i in range(10):
        subgroup_name= f'here{i:06d}'
        subgroup= group.create_group(subgroup_name)
        for j in range(11):
            subgroup.create_dataset(f'tile_{j}', data=1)

# %%
with h5py.File('test','r') as h5:
    print(h5['train/here000000/tile_0'])
# Out:
# <HDF5 dataset "tile_0": shape (), type "<i8">
